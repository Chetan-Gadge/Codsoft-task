# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
credit_data = pd.read_csv("fraudTest.csv")
credit_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659
# 1  Williams      F             3638 Marsh Union  ...  40.3207
# ...

# %%
credit_data.tail()
# Out:
#       Unnamed: 0 trans_date_trans_time               cc_num  \
# 3896        3896   2020-06-22 13:26:11  4792627764422477317
# 3897        3897   2020-06-22 13:26:23     5580563567307107
# 3898        3898   2020-06-22 13:26:45     4170689372027579
# 3899        3899   2020-06-22 13:26:45     3523898249167098
# 3900        3900   2020-06-22 13:26:53  4710826438164847414
#
#                               merchant   category     amt     first  \
# 3896  fraud_Koss, Hansen and Lueilwitz       home   76.72  Margaret
# 3897            fraud_Leannon-Nikolaus     travel  477.66   Stanley
# 3898  fraud_Koss, Hansen and Lueilwitz       home  217.07    Samuel
# 3899                fraud_Schmeler Inc   misc_pos  100.41    Joshua
# 3900                 fraud_Bode-Rempel  kids_pets  137.92      Juan
#
#            last gender                      street  ...      lat      long  \
# 3896     Mendez      F             7952 Karen Pike  ...  38.9462  -94.9714
# ...

# %%
credit_data.shape
# Out:
# (3901, 23)

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3901 entries, 0 to 3900
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3901 non-null   int64
#  1   trans_date_trans_time  3901 non-null   object
#  2   cc_num                 3901 non-null   int64
#  3   merchant               3901 non-null   object
#  4   category               3901 non-null   object
#  5   amt                    3901 non-null   float64
#  6   first                  3901 non-null   object
#  7   last                   3901 non-null   object
#  8   gender                 3901 non-null   object
#  9   street                 3901 non-null   object
#  10  city                   3901 non-null   object
#  11  state                  3901 non-null   object
#  12  zip                    3901 non-null   int64
#  13  lat                    3901 non-null   float64
# ...

# %%
#check null values
credit_data.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
credit_data.describe()
# Out:
#         Unnamed: 0        cc_num          amt           zip         lat  \
# count  3901.000000  3.901000e+03  3901.000000   3901.000000  3901.00000
# mean   1950.000000  3.960435e+17    70.102025  48573.997693    38.43053
# std    1126.266028  1.282686e+18   131.248264  26645.770145     5.11427
# min       0.000000  6.041621e+10     1.010000   1257.000000    20.02710
# 25%     975.000000  1.800490e+14     9.720000  26339.000000    34.50910
# 50%    1950.000000  3.521417e+15    47.430000  47451.000000    39.20920
# 75%    2925.000000  4.642255e+15    81.420000  72011.000000    41.89480
# max    3900.000000  4.992346e+18  3204.980000  99783.000000    65.68990
#
#            city_pop     unix_time    merch_lat   merch_long     is_fraud
# count  3.900000e+03  3.900000e+03  3900.000000  3900.000000  3900.000000
# mean   1.054265e+05  1.371861e+09    38.420801   -89.959054     0.004615
# std    3.505800e+05  2.717695e+04     5.144444    13.519088     0.067788
# ...

# %%
credit_data.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
credit_data = pd.read_csv("fraudTest.csv")
credit_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659
# 1  Williams      F             3638 Marsh Union  ...  40.3207
# ...

# %%
print(credit_data.columns)
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
import pandas as pd
credit_data = pd.read_csv("fraudTrain.csv")

    # Remove leading/trailing spaces from column names
credit_data.columns = credit_data.columns.str.strip()

fraud_case = credit_data[credit_data == 1]
valid_case = credit_data[credit_data == 0]

print(f"Number of Fraud Case: {len(fraud_case)}")
print(f"Number of Valid Case: {len(valid_case)}")

total =  len(fraud_case) / len(valid_case)
total
# Out:
# Number of Fraud Case: 8181
# Number of Valid Case: 8181
# 1.0

# %%
per = len(fraud_case) / len(credit_data) * 100
per
# Out:
# 100.0

# %%
# Count the number of occurrences for each class (0 for legitimate, 1 for fraudulent)
class_counts = credit_data.value_counts()

# Calculate the percentage of fraudulent transactions
percentage_fraudulent = (class_counts[1] / class_counts.sum()) * 100

plt.figure(figsize=(8, 6))
sns.countplot(x='is_fraud', data=credit_data)
plt.title('Distribution of Legitimate vs. Fraudulent Transactions')
plt.xlabel('Class (0: Legitimate, 1: Fraudulent)')
plt.ylabel('Count')

# Display the percentage of fraudulent transactions on the plot


plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of transaction times
plt.figure(figsize=(10, 6))
sns.histplot(credit_data, bins=48, kde=True)  # Using 48 bins for a daily view
plt.title('Transaction Time Distribution')
plt.xlabel('Time (in seconds)')
plt.ylabel('Count')

# Check if there are specific times of day when fraud is more likely to occur
plt.figure(figsize=(10, 6))
sns.histplot(credit_data[credit_data == 2], bins=48, kde=True, color='red', label='Fraudulent')
sns.histplot(credit_data[credit_data == 0], bins=48, kde=True, color='blue', label='Legitimate')
plt.title('Fraud vs. Legitimate Transaction Time Distribution')
plt.xlabel('Time (in seconds)')
plt.ylabel('Count')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_kde.py in __init__(self, dataset, bw_method, weights)
#     225         try:
# --> 226             self.set_bandwidth(bw_method=bw_method)
#     227         except linalg.LinAlgError as e:
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_kde.py in set_bandwidth(self, bw_method)
#     573
# --> 574         self._compute_covariance()
#     575
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_kde.py in _compute_covariance(self)
#     585                                                aweights=self.weights))
# --> 586             self._data_cho_cov = linalg.cholesky(self._data_covariance,
#     587                                                  lower=True)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
# Select only numeric features for correlation calculation
numeric_data = credit_data.select_dtypes(include=['number'])

correlation_matrix = numeric_data.corr()
print(correlation_matrix)

# Filter the correlations of features with the target variable ('Class')
feature_correlations = correlation_matrix['is_fraud'].drop('is_fraud')  # Assuming 'is_fraud' is your target variable
print(feature_correlations)

correlation_threshold = 0.1

highly_correlated_features = feature_correlations[abs(feature_correlations) > correlation_threshold]

plt.figure(figsize=(12, 6))
sns.barplot(x=highly_correlated_features.index, y=highly_correlated_features.values, palette='viridis')
plt.title('Feature Correlations with Fraud (Class)')
plt.xlabel('Features')
plt.ylabel('Correlation')
plt.xticks(rotation=45)

plt.show()
# Out:
#                class    cc_num       amt       zip       lat      long  \
# class       1.000000  0.001206  0.020911 -0.005128  0.014615 -0.007241
# cc_num      0.001206  1.000000 -0.010795  0.044466 -0.085012 -0.060095
# amt         0.020911 -0.010795  1.000000  0.009120  0.057264 -0.039710
# zip        -0.005128  0.044466  0.009120  1.000000 -0.084263 -0.898025
# lat         0.014615 -0.085012  0.057264 -0.084263  1.000000 -0.063610
# long       -0.007241 -0.060095 -0.039710 -0.898025 -0.063610  1.000000
# city_pop    0.009524 -0.004414  0.003269  0.063767 -0.157194 -0.030754
# unix_time   0.996215  0.001389  0.023730 -0.005723  0.014301 -0.007377
# merch_lat   0.014361 -0.085790  0.057694 -0.083212  0.993911 -0.063732
# merch_long -0.007290 -0.060207 -0.039240 -0.897446 -0.063519  0.999207
# is_fraud    0.039593 -0.023446  0.301906  0.025820  0.105309 -0.111109
#
#             city_pop  unix_time  merch_lat  merch_long  is_fraud
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you want 'trans_time' for x, 'amt' for y, and 'is_fraud' for color:
plt.figure(figsize=(10, 6))
# Extract the relevant columns from your DataFrame
x_data = pd.to_numeric(credit_data['trans_date_trans_time'].str.split(' ').str[1].str.split(':').str[0])
y_data = credit_data['amt']
color_data = credit_data['is_fraud']

# Create the scatter plot
plt.scatter(x_data, y_data, c=color_data, cmap='coolwarm', alpha=0.5)

plt.title('Transaction Amount vs. Time')
plt.xlabel('Time (hours)')  # Changed x-axis label to 'hours'
plt.ylabel('Transaction Amount')
plt.colorbar(label='Class (0: Legitimate, 1: Fraudulent)')

plt.show()

# %%
# Calculate the correlation matrix
# Select only numeric features for correlation calculation
correlation_matrix = credit_data.select_dtypes(include=['number']).corr() # Select only numeric columns before calling .corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False, fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap Between Features')
plt.show()

# %%
# import libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix)

# %%
# Assuming 'is_fraud' is the target variable and you want to drop it from X
X = credit_data.drop(columns=['is_fraud'])
# Target value
Y = credit_data['is_fraud']

print(f"value and shapes : {X.values,X.shape}")
print(f"value and shapes : {Y.values,Y.shape}")
# Out:
# value and shapes : (array([[0, '01-01-2019 00:00', 2703190000000000.0, ..., 1325376018,
#         36.011293, -82.048315],
#        [1, '01-01-2019 00:00', 630423000000.0, ..., 1325376044,
#         49.159047, -118.186462],
#        [2, '01-01-2019 00:00', 38859500000000.0, ..., 1325376051,
#         43.150704, -112.154481],
#        ...,
#        [8178, '06-01-2019 07:38', 379141000000000.0, ..., 1325835494,
#         33.858628, -81.033704],
#        [8179, '06-01-2019 07:38', 3540080000000000.0, ..., 1325835495,
#         45.061019, -93.603629],
#        [8180, '06-01-2019 07:40', 4.50254e+18, ..., 1325835612, 36.379,
#         nan]], dtype=object), (8181, 22))
# value and shapes : (array([ 0.,  0.,  0., ...,  0.,  0., nan]), (8181,))

# %%
X_train,X_test, Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 42)

# %%
# import libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix)
from sklearn.preprocessing import LabelEncoder

# Assuming 'is_fraud' is the target variable and you want to drop it from X
X = credit_data.drop(columns=['is_fraud'])
# Target value
Y = credit_data['is_fraud']

# Create a copy of X to avoid modifying the original DataFrame
X_encoded = X.copy()

# Convert 'trans_date_trans_time' to numerical representation
#  Replace this with the actual logic to convert date/time to numbers
for index, row in X_encoded.iterrows():
    date_time_str = row['trans_date_trans_time']
    # Example: Split the string and convert parts to integers
    date_parts = date_time_str.split(' ')[0].split('-')  # Split date
    time_parts = date_time_str.split(' ')[1].split(':')  # Split time

    # Combine the parts into a numerical representation (adjust as needed)
    numerical_representation = int(date_parts[0] + date_parts[1] + date_parts[2] + time_parts[0] + time_parts[1])

    X_encoded.at[index, 'trans_date_trans_time'] = numerical_representation

# Convert categorical features (like 'merchant') to numerical using Label Encoding
for col in X_encoded.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    X_encoded[col] = le.fit_transform(X_encoded[col])

X_train,X_test, Y_train,Y_test = train_test_split(X_encoded,Y,test_size = 0.2, random_state = 42)

model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model on the training data
model.fit(X_train,Y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# %%
print(y_pred)
print(Y_test)
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# 2464    0.0
# 7286    0.0
# 3862    0.0
# 6884    0.0
# 4098    0.0
#        ...
# 84      0.0
# 7414    0.0
# 6940    0.0
# 2987    0.0
# 7773    0.0
# Name: is_fraud, Length: 1637, dtype: float64

# %%
# Option 2: Fill missing values with a specific value (e.g., 0)
credit_data['is_fraud'] = credit_data['is_fraud'].fillna(0)
X = credit_data.drop(columns=['is_fraud'])
Y = credit_data['is_fraud']
